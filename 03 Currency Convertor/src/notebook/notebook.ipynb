# %%
import requests

# %%
def get_exchange_rate(API_KEY, base_currency, target_currency):
    url = f'https://v6.exchangerate-api.com/v6/{API_KEY}/latest/{base_currency}'
    response = requests.get(url)
    return response.json()['conversion_rates'][target_currency]

# %%
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("API_KEY")

# %%
base_currency = 'USD'
target_currency = 'CAD'

# %%
def convert_currency(amount, exchange_amount):
    return amount * exchange_amount

# %%
# Out:
# 1.387

# %%
url = f'https://v6.exchangerate-api.com/v6/{API_KEY}/latest/{base_currency}'
response = requests.get(url)

# %%
response.json()
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1755734401,
#  'time_last_update_utc': 'Thu, 21 Aug 2025 00:00:01 +0000',
#  'time_next_update_unix': 1755820801,
#  'time_next_update_utc': 'Fri, 22 Aug 2025 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 68.9345,
#   'ALL': 83.3936,
#   'AMD': 382.5324,
#   'ANG': 1.79,
#   'AOA': 918.0887,
#   'ARS': 1298.5,
#   'AUD': 1.5544,
#   'AWG': 1.79,
#   'AZN': 1.6989,
#   'BAM': 1.679,
#   'BBD': 2.0,
#   'BDT': 121.4656,
#   'BGN': 1.679,
#   'BHD': 0.376,
#   'BIF': 2980.4854,
#   'BMD': 1.0,
#   'BND': 1.2852,
#   'BOB': 6.9258,
#   'BRL': 5.4784,
#   'BSD': 1.0,
#   'BTN': 87.0709,
#   'BWP': 13.7767,
#   'BYN': 3.2534,
#   'BZD': 2.0,
#   'CAD': 1.387,
#   'CDF': 2887.4395,
#   'CHF': 0.8051,
#   'CLP': 963.175,
#   'CNY': 7.1824,
#   'COP': 4025.5617,
#   'CRC': 504.9784,
#   'CUP': 24.0,
#   'CVE': 94.6598,
#   'CZK': 21.0171,
#   'DJF': 177.721,
#   'DKK': 6.4054,
#   'DOP': 61.8242,
#   'DZD': 129.8234,
#   'EGP': 48.5879,
#   'ERN': 15.0,
#   'ETB': 140.6255,
#   'EUR': 0.8585,
#   'FJD': 2.2707,
#   'FKP': 0.7427,
#   'FOK': 6.4053,
#   'GBP': 0.7427,
#   'GEL': 2.697,
#   'GGP': 0.7427,
#   'GHS': 11.2235,
#   'GIP': 0.7427,
#   'GMD': 72.848,
#   'GNF': 8681.5242,
#   'GTQ': 7.6583,
#   'GYD': 209.0562,
#   'HKD': 7.8123,
#   'HNL': 26.1915,
#   'HRK': 6.4682,
#   'HTG': 130.7889,
#   'HUF': 338.7361,
#   'IDR': 16287.9184,
#   'ILS': 3.4074,
#   'IMP': 0.7427,
#   'INR': 87.071,
#   'IQD': 1309.2125,
#   'IRR': 42280.0188,
#   'ISK': 123.1117,
#   'JEP': 0.7427,
#   'JMD': 160.0688,
#   'JOD': 0.709,
#   'JPY': 147.3628,
#   'KES': 129.0762,
#   'KGS': 87.3116,
#   'KHR': 4009.2829,
#   'KID': 1.5543,
#   'KMF': 422.3423,
#   'KRW': 1397.0846,
#   'KWD': 0.3055,
#   'KYD': 0.8333,
#   'KZT': 538.1585,
#   'LAK': 21621.769,
#   'LBP': 89500.0,
#   'LKR': 301.3664,
#   'LRD': 200.4033,
#   'LSL': 17.6829,
#   'LYD': 5.4178,
#   'MAD': 9.0088,
#   'MDL': 16.7301,
#   'MGA': 4418.1764,
#   'MKD': 52.7503,
#   'MMK': 2099.1889,
#   'MNT': 3586.6871,
#   'MOP': 8.0473,
#   'MRU': 40.0167,
#   'MUR': 45.7768,
#   'MVR': 15.4364,
#   'MWK': 1738.9927,
#   'MXN': 18.7755,
#   'MYR': 4.2258,
#   'MZN': 63.6542,
#   'NAD': 17.6829,
#   'NGN': 1534.95,
#   'NIO': 36.7682,
#   'NOK': 10.2449,
#   'NPR': 139.3134,
#   'NZD': 1.7167,
#   'OMR': 0.3845,
#   'PAB': 1.0,
#   'PEN': 3.5054,
#   'PGK': 4.2201,
#   'PHP': 57.062,
#   'PKR': 283.2081,
#   'PLN': 3.6469,
#   'PYG': 7309.4282,
#   'QAR': 3.64,
#   'RON': 4.341,
#   'RSD': 100.5506,
#   'RUB': 80.241,
#   'RWF': 1448.8504,
#   'SAR': 3.75,
#   'SBD': 8.2047,
#   'SCR': 14.7444,
#   'SDG': 543.7714,
#   'SEK': 9.5928,
#   'SGD': 1.2853,
#   'SHP': 0.7427,
#   'SLE': 23.2756,
#   'SLL': 23275.6134,
#   'SOS': 571.2292,
#   'SRD': 37.6586,
#   'SSP': 4611.9257,
#   'STN': 21.0327,
#   'SYP': 12926.9122,
#   'SZL': 17.6829,
#   'THB': 32.5604,
#   'TJS': 9.3496,
#   'TMT': 3.4979,
#   'TND': 2.8819,
#   'TOP': 2.3525,
#   'TRY': 40.934,
#   'TTD': 6.7678,
#   'TVD': 1.5543,
#   'TWD': 30.2561,
#   'TZS': 2484.5362,
#   'UAH': 41.3929,
#   'UGX': 3545.6509,
#   'UYU': 40.1283,
#   'UZS': 12542.0165,
#   'VES': 139.4016,
#   'VND': 26242.8231,
#   'VUV': 119.6985,
#   'WST': 2.7138,
#   'XAF': 563.123,
#   'XCD': 2.7,
#   'XCG': 1.79,
#   'XDR': 0.7324,
#   'XOF': 563.123,
#   'XPF': 102.4436,
#   'YER': 239.957,
#   'ZAR': 17.6832,
#   'ZMW': 23.3177,
#   'ZWL': 26.7807}}

# %%
params = {'q': 'Python Programming'}

# %%
requests.get(url, params=params)
# Out:
# <Response [403]>
